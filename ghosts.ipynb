# %%
import pandas as pd

ghosts =  {
    "Nombre": ['Hetty', 'Isaac', 'Alberta', 'Pete', 'Sassappis', 'Flower', 'Trevor', 'Thorfinn', 'Patience', 'Stephanie'],
    "Edad": [45, 35, 38, 41, 25, 31, 33, 38, 40, 18],
    "Año de muerte": [1895, 1777, 1928, 1985, 1513, 1969, 2000, 1007, 1692, 1987],
    "Poder": ["San Patricio", "Olor", "Cantar", "Sin límite", "Sueños", "Porros", "Tocar cosas", "Rayos", "Jesucristo", "No tiene"],
    "Relación": ["Por supuesto", "No", "Sí", "Sí", "Sí", "Sí", "Por supuesto", "Sí", "No", "No"]
}

ghosts = pd.DataFrame(ghosts)

ghosts["Causa de muerte"] = ["Estrangulación", "Disentería", "Envenenada", "Flecha", "Desconocida", "Ataque de oso", "Sobredosis", "Electrocutado", "Flebotomía", "Asesino en serie"]

ghosts_edad = ghosts.sort_values(by="Edad", ascending=False)

ghosts_poderes = ghosts[["Nombre","Poder"]]

ghosts_mayores = ghosts[ghosts["Edad"] > 35]

# %%
ghosts

# %%
import pandas as pd

ghosts =  {
    "Nombre": ['Hetty', 'Isaac', 'Alberta', 'Pete', 'Sassappis', 'Flower', 'Trevor', 'Thorfinn', 'Patience', 'Stephanie'],
    "Edad": [45, 35, 38, 41, 25, 31, 33, 38, 40, 18],
    "Año de muerte": [1895, 1777, 1928, 1985, 1513, 1969, 2000, 1007, 1692, 1987],
    "Poder": ["San Patricio", "Olor", "Cantar", "Sin límite", "Sueños", "Porros", "Tocar cosas", "Rayos", "Jesucristo", "No tiene"],
    "Relación": ["Por supuesto", "No", "Sí", "Sí", "Sí", "Sí", "Por supuesto", "Sí", "No", "No"]
}

ghosts = pd.DataFrame(ghosts)

ghosts["Causa de muerte"] = ["Estrangulación", "Disentería", "Envenenada", "Flecha", "Desconocida", "Ataque de oso", "Sobredosis", "Electrocutado", "Flebotomía", "Asesino en serie"]

ghosts_edad = ghosts.sort_values(by="Edad", ascending=False)

ghosts_poderes = ghosts[["Nombre","Poder"]]

ghosts_mayores = ghosts[ghosts["Edad"] > 35]

# %%
ghosts

# %%
import pandas as pd

# %%
ghosts =  {
    "Nombre": ['Hetty', 'Isaac', 'Alberta', 'Pete', 'Sassappis', 'Flower', 'Trevor', 'Thorfinn', 'Patience', 'Stephanie'],
    "Edad": [45, 35, 38, 41, 25, 31, 33, 38, 40, 18],
    "Año de muerte": [1895, 1777, 1928, 1985, 1513, 1969, 2000, 1007, 1692, 1987],
    "Poder": ["San Patricio", "Olor", "Cantar", "Sin límite", "Sueños", "Porros", "Tocar cosas", "Rayos", "Jesucristo", "No tiene"],
    "Relación": ["Por supuesto", "No", "Sí", "Sí", "Sí", "Sí", "Por supuesto", "Sí", "No", "No"]
}

ghosts = pd.DataFrame(ghosts)

ghosts["Causa de muerte"] = ["Estrangulación", "Disentería", "Envenenada", "Flecha", "Desconocida", "Ataque de oso", "Sobredosis", "Electrocutado", "Flebotomía", "Asesino en serie"]

ghosts_edad = ghosts.sort_values(by="Edad", ascending=False)

ghosts_poderes = ghosts[["Nombre","Poder"]]

ghosts_mayores = ghosts[ghosts["Edad"] > 35]

# %%
ghosts
# Out:
#       Nombre  Edad  Año de muerte         Poder      Relación  \
# 0      Hetty    45           1895  San Patricio  Por supuesto
# 1      Isaac    35           1777          Olor            No
# 2    Alberta    38           1928        Cantar            Sí
# 3       Pete    41           1985    Sin límite            Sí
# 4  Sassappis    25           1513        Sueños            Sí
# 5     Flower    31           1969        Porros            Sí
# 6     Trevor    33           2000   Tocar cosas  Por supuesto
# 7   Thorfinn    38           1007         Rayos            Sí
# 8   Patience    40           1692    Jesucristo            No
# 9  Stephanie    18           1987      No tiene            No
#
#     Causa de muerte
# 0    Estrangulación
# 1        Disentería
# 2        Envenenada
# 3            Flecha
# 4       Desconocida
# 5     Ataque de oso
# 6        Sobredosis
# 7     Electrocutado
# 8        Flebotomía
# 9  Asesino en serie

# %%
ghosts =  {
    "Nombre": ['Hetty', 'Isaac', 'Alberta', 'Pete', 'Sassappis', 'Flower', 'Trevor', 'Thorfinn', 'Patience', 'Stephanie'],
    "Edad": [45, 35, 38, 41, 25, 31, 33, 38, 40, 18],
    "Año de muerte": [1895, 1777, 1928, 1985, 1513, 1969, 2000, 1007, 1692, 1987],
    "Poder": ["San Patricio", "Olor", "Cantar", "Sin límite", "Sueños", "Porros", "Tocar cosas", "Rayos", "Jesucristo", "No tiene"],
    "Relación": ["Por supuesto", "No", "Sí", "Sí", "Sí", "Sí", "Por supuesto", "Sí", "No", "No"]
}

ghosts = pd.DataFrame(ghosts)

ghosts["Causa de muerte"] = ["Estrangulación", "Disentería", "Envenenada", "Flecha", "Desconocida", "Ataque de oso", "Sobredosis", "Electrocutado", "Flebotomía", "Asesino en serie"]

ghosts_edad = ghosts.sort_values(by="Edad", ascending=False)

ghosts_poderes = ghosts[["Nombre","Poder"]]

ghosts_mayores = ghosts[ghosts["Edad"] > 35]

# %%
import pandas as pd

# %%
ghosts =  {
    "Nombre": ['Hetty', 'Isaac', 'Alberta', 'Pete', 'Sassappis', 'Flower', 'Trevor', 'Thorfinn', 'Patience', 'Stephanie'],
    "Edad": [45, 35, 38, 41, 25, 31, 33, 38, 40, 18],
    "Año de muerte": [1895, 1777, 1928, 1985, 1513, 1969, 2000, 1007, 1692, 1987],
    "Poder": ["San Patricio", "Olor", "Cantar", "Sin límite", "Sueños", "Porros", "Tocar cosas", "Rayos", "Jesucristo", "No tiene"],
    "Relación": ["Por supuesto", "No", "Sí", "Sí", "Sí", "Sí", "Por supuesto", "Sí", "No", "No"]
}

ghosts = pd.DataFrame(ghosts)

ghosts["Causa de muerte"] = ["Estrangulación", "Disentería", "Envenenada", "Flecha", "Desconocida", "Ataque de oso", "Sobredosis", "Electrocutado", "Flebotomía", "Asesino en serie"]

ghosts_edad = ghosts.sort_values(by="Edad", ascending=False)

ghosts_poderes = ghosts[["Nombre","Poder"]]

ghosts_mayores = ghosts[ghosts["Edad"] > 35]

# %%
ghosts
# Out:
#       Nombre  Edad  Año de muerte         Poder      Relación  \
# 0      Hetty    45           1895  San Patricio  Por supuesto
# 1      Isaac    35           1777          Olor            No
# 2    Alberta    38           1928        Cantar            Sí
# 3       Pete    41           1985    Sin límite            Sí
# 4  Sassappis    25           1513        Sueños            Sí
# 5     Flower    31           1969        Porros            Sí
# 6     Trevor    33           2000   Tocar cosas  Por supuesto
# 7   Thorfinn    38           1007         Rayos            Sí
# 8   Patience    40           1692    Jesucristo            No
# 9  Stephanie    18           1987      No tiene            No
#
#     Causa de muerte
# 0    Estrangulación
# 1        Disentería
# 2        Envenenada
# 3            Flecha
# 4       Desconocida
# 5     Ataque de oso
# 6        Sobredosis
# 7     Electrocutado
# 8        Flebotomía
# 9  Asesino en serie

# %%
ghosts
# Out:
#       Nombre  Edad  Año de muerte         Poder      Relación  \
# 0      Hetty    45           1895  San Patricio  Por supuesto
# 1      Isaac    35           1777          Olor            No
# 2    Alberta    38           1928        Cantar            Sí
# 3       Pete    41           1985    Sin límite            Sí
# 4  Sassappis    25           1513        Sueños            Sí
# 5     Flower    31           1969        Porros            Sí
# 6     Trevor    33           2000   Tocar cosas  Por supuesto
# 7   Thorfinn    38           1007         Rayos            Sí
# 8   Patience    40           1692    Jesucristo            No
# 9  Stephanie    18           1987      No tiene            No
#
#     Causa de muerte
# 0    Estrangulación
# 1        Disentería
# 2        Envenenada
# 3            Flecha
# 4       Desconocida
# 5     Ataque de oso
# 6        Sobredosis
# 7     Electrocutado
# 8        Flebotomía
# 9  Asesino en serie

# %%
ghosts_mayores
# Out:
#      Nombre  Edad  Año de muerte         Poder      Relación Causa de muerte
# 0     Hetty    45           1895  San Patricio  Por supuesto  Estrangulación
# 2   Alberta    38           1928        Cantar            Sí      Envenenada
# 3      Pete    41           1985    Sin límite            Sí          Flecha
# 7  Thorfinn    38           1007         Rayos            Sí   Electrocutado
# 8  Patience    40           1692    Jesucristo            No      Flebotomía

# %%
import pandas as pd

ghosts =  {
    "Nombre": ['Hetty', 'Isaac', 'Alberta', 'Pete', 'Sassappis', 'Flower', 'Trevor', 'Thorfinn', 'Patience', 'Stephanie'],
    "Edad": [45, 35, 38, 41, 25, 31, 33, 38, 40, 18],
    "Año de muerte": [1895, 1777, 1928, 1985, 1513, 1969, 2000, 1007, 1692, 1987],
    "Poder": ["San Patricio", "Olor", "Cantar", "Sin límite", "Sueños", "Porros", "Tocar cosas", "Rayos", "Jesucristo", "No tiene"],
    "Relación": ["Por supuesto", "No", "Sí", "Sí", "Sí", "Sí", "Por supuesto", "Sí", "No", "No"]
}

ghosts = pd.DataFrame(ghosts)

ghosts["Causa de muerte"] = ["Estrangulación", "Disentería", "Envenenada", "Flecha", "Desconocida", "Ataque de oso", "Sobredosis", "Electrocutado", "Flebotomía", "Asesino en serie"]

ghosts_edad = ghosts.sort_values(by="Edad", ascending=False)

ghosts_poderes = ghosts[["Nombre","Poder"]]

ghosts_mayores = ghosts[ghosts["Edad"] > 35]

ghosts
# Out:
#       Nombre  Edad  Año de muerte         Poder      Relación  \
# 0      Hetty    45           1895  San Patricio  Por supuesto
# 1      Isaac    35           1777          Olor            No
# 2    Alberta    38           1928        Cantar            Sí
# 3       Pete    41           1985    Sin límite            Sí
# 4  Sassappis    25           1513        Sueños            Sí
# 5     Flower    31           1969        Porros            Sí
# 6     Trevor    33           2000   Tocar cosas  Por supuesto
# 7   Thorfinn    38           1007         Rayos            Sí
# 8   Patience    40           1692    Jesucristo            No
# 9  Stephanie    18           1987      No tiene            No
#
#     Causa de muerte
# 0    Estrangulación
# 1        Disentería
# 2        Envenenada
# 3            Flecha
# 4       Desconocida
# 5     Ataque de oso
# 6        Sobredosis
# 7     Electrocutado
# 8        Flebotomía
# 9  Asesino en serie
